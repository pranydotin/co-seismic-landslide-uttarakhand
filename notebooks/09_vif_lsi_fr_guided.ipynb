# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv(
    "/content/drive/MyDrive/cosesmic/csv/final_ml_dataset_clean.csv"
)

# %%
df.shape
# Out:
# (30781, 19)

# %%
df.head()
# Out:
#    ASPECT_11  ELEVATION_11  SLOPE_11  PLAN_CURV_11  PROFILE_CURV_11  \
# 0          3    679.130005  0.276021     -0.016538        -0.008122
# 1          4    913.332825  0.632032      0.000268        -0.000074
# 2          8    721.089966  0.681697     -0.008121         0.000211
# 3          3    758.113342  0.561121     -0.002347        -0.000685
# 4          2    731.924133  0.589670     -0.007241         0.001289
#
#       TWI_11     TRI_11   NDVI_11  LULC_11  PROXIMITY_ROADS_11  \
# 0  15.716049   7.545804  0.160194       30            0.000000
# 1   5.646492  13.151764  0.295511       30          108.166534
# 2   7.185718  14.802107  0.268077       10           60.000000
# 3   6.366368  11.326160  0.243862       30          240.000000
# 4   7.196071  12.147046  0.338092       30          108.166534
#
#    PROXIMITY_RIVERS_11  PROXIMITY_FAULTS_11  MAX_RAINFALL_11  \
# 0             1.414214          2658.006836       529.694031
# 1            16.000000          3178.442871       547.740418
# 2             8.062258          1397.175781       529.694031
# 3            15.000000          2992.340332       529.694031
# 4             6.708204          1855.397583       529.694031
#
#    MEAN_RAINFALL_11  MONSOON_RAINFALL_11  FLOW_ACC_11  label     X_COORD  \
# 0        121.518135           258.144958    17.800678      1  401540.952
# 1        118.726166           252.454834     8.681055      1  400035.083
# 2        121.518135           258.144958    10.322898      1  403318.553
# 3        121.518135           258.144958     9.248116      1  400375.404
# 4        121.518135           258.144958    10.140306      1  402218.711
#
#        Y_COORD
# 0  3261698.480
# 1  3261801.147
# 2  3261938.765
# 3  3262129.371
# 4  3262123.997

# %%
features = [
    col for col in df.columns
    if col not in [
        'X_COORD',
        'Y_COORD',
        'label'
    ]
]

# %%
X = df[features]
y = df['label']

# %%
print(X.columns.tolist())
# Out:
# ['ASPECT_11', 'ELEVATION_11', 'SLOPE_11', 'PLAN_CURV_11', 'PROFILE_CURV_11', 'TWI_11', 'TRI_11', 'NDVI_11', 'LULC_11', 'PROXIMITY_ROADS_11', 'PROXIMITY_RIVERS_11', 'PROXIMITY_FAULTS_11', 'MAX_RAINFALL_11', 'MEAN_RAINFALL_11', 'MONSOON_RAINFALL_11', 'FLOW_ACC_11']

# %%
def calculate_vif(df):

    vif_data = pd.DataFrame()

    vif_data["Feature"] = df.columns

    vif_data["VIF"] = [
        variance_inflation_factor(df.values, i)
        for i in range(df.shape[1])
    ]

    return vif_data.sort_values(
        by="VIF",
        ascending=False
    ).reset_index(drop=True)

# %%
print(calculate_vif(X))
# Out:
#                 Feature         VIF
# 0   MONSOON_RAINFALL_11  715.679995
# 1      MEAN_RAINFALL_11  714.389240
# 2           FLOW_ACC_11  685.381215
# 3                TWI_11  366.245696
# 4       MAX_RAINFALL_11  203.118067
# 5              SLOPE_11   32.919515
# 6          ELEVATION_11   15.686964
# 7               NDVI_11    6.894818
# 8               LULC_11    5.947285
# 9             ASPECT_11    5.275575
# 10   PROXIMITY_ROADS_11    3.890449
# 11  PROXIMITY_RIVERS_11    2.987224
# 12  PROXIMITY_FAULTS_11    2.403258
# 13      PROFILE_CURV_11    2.343923
# 14         PLAN_CURV_11    2.278846
# 15               TRI_11    1.519483

# %%
def reduce_multicollinearity(
    df,
    threshold=10.0,
    protected_features=None
):

    if protected_features is None:
        protected_features = []

    while True:

        vif_df = calculate_vif(df)

        print("\n--- Current VIF Scores ---")

        print(vif_df)

        highest_vif = vif_df.iloc[0]["VIF"]

        highest_feature = vif_df.iloc[0]["Feature"]

        if highest_vif > threshold:

            if highest_feature in protected_features:

                found_alternative = False

                for i in range(1, len(vif_df)):

                    next_feature = vif_df.iloc[i]["Feature"]

                    next_vif = vif_df.iloc[i]["VIF"]

                    if (
                        next_feature not in protected_features
                        and next_vif > threshold
                    ):

                        print(
                            f"Skipping protected feature "
                            f"'{highest_feature}' "
                            f"({highest_vif:.2f})"
                        )

                        print(
                            f"Dropping next highest culprit: "
                            f"'{next_feature}' "
                            f"({next_vif:.2f})"
                        )

                        df = df.drop(columns=[next_feature])

                        found_alternative = True

                        break

                if not found_alternative:

                    print(
                        "\nAll remaining features "
                        "above threshold are protected."
                    )

                    break

            else:

                print(
                    f"Dropping: '{highest_feature}' "
                    f"with VIF: {highest_vif:.2f}"
                )

                df = df.drop(columns=[highest_feature])

        else:

            print(
                f"\nSuccess! All features "
                f"below threshold {threshold}"
            )

            break

    return df

# %%
critical_layers = ['ELEVATION_11']

# %%
final_features_df = reduce_multicollinearity(X, threshold=10.0, protected_features=critical_layers)
# Out:
# --- Current VIF Scores ---
#                 Feature         VIF
# 0   MONSOON_RAINFALL_11  715.679995
# 1      MEAN_RAINFALL_11  714.389240
# 2           FLOW_ACC_11  685.381215
# 3                TWI_11  366.245696
# 4       MAX_RAINFALL_11  203.118067
# 5              SLOPE_11   32.919515
# 6          ELEVATION_11   15.686964
# 7               NDVI_11    6.894818
# 8               LULC_11    5.947285
# 9             ASPECT_11    5.275575
# 10   PROXIMITY_ROADS_11    3.890449
# 11  PROXIMITY_RIVERS_11    2.987224
# 12  PROXIMITY_FAULTS_11    2.403258
# 13      PROFILE_CURV_11    2.343923
# 14         PLAN_CURV_11    2.278846
# 15               TRI_11    1.519483
# Dropping: 'MONSOON_RAINFALL_11' with VIF: 715.68
#
# --- Current VIF Scores ---
#                 Feature         VIF
# 0           FLOW_ACC_11  678.733752
# 1                TWI_11  365.531670
# 2      MEAN_RAINFALL_11  229.521477
# 3       MAX_RAINFALL_11  140.538025
# 4              SLOPE_11   32.849243
# 5          ELEVATION_11   13.090151
# 6               NDVI_11    6.857469
# 7               LULC_11    5.944744
# 8             ASPECT_11    5.268024
# 9    PROXIMITY_ROADS_11    3.826463
# 10  PROXIMITY_RIVERS_11    2.953728
# 11  PROXIMITY_FAULTS_11    2.402397
# 12      PROFILE_CURV_11    2.341932
# 13         PLAN_CURV_11    2.275569
# 14               TRI_11    1.518334
# Dropping: 'FLOW_ACC_11' with VIF: 678.73
#
# --- Current VIF Scores ---
#                 Feature         VIF
# 0      MEAN_RAINFALL_11  215.756126
# 1       MAX_RAINFALL_11  136.747715
# 2          ELEVATION_11   12.503229
# 3                TWI_11   12.437885
# 4              SLOPE_11    9.860449
# 5               NDVI_11    6.501468
# 6               LULC_11    5.892080
# 7             ASPECT_11    5.244920
# 8    PROXIMITY_ROADS_11    3.728342
# 9   PROXIMITY_RIVERS_11    2.951391
# 10  PROXIMITY_FAULTS_11    2.398626
# 11      PROFILE_CURV_11    2.334917
# 12         PLAN_CURV_11    2.267698
# 13               TRI_11    1.517457
# Dropping: 'MEAN_RAINFALL_11' with VIF: 215.76
#
# --- Current VIF Scores ---
#                 Feature        VIF
# 0          ELEVATION_11  12.498673
# 1       MAX_RAINFALL_11  10.818169
# 2                TWI_11  10.187518
# 3              SLOPE_11   8.729393
# 4               NDVI_11   5.980048
# 5               LULC_11   5.842884
# 6             ASPECT_11   5.196295
# 7    PROXIMITY_ROADS_11   3.720615
# 8   PROXIMITY_RIVERS_11   2.931764
# 9   PROXIMITY_FAULTS_11   2.392988
# 10      PROFILE_CURV_11   2.332447
# 11         PLAN_CURV_11   2.266269
# 12               TRI_11   1.516390
# Skipping protected feature 'ELEVATION_11' (12.50)
# Dropping next highest culprit: 'MAX_RAINFALL_11' (10.82)
#
# --- Current VIF Scores ---
#                 Feature        VIF
# 0          ELEVATION_11  12.482052
# 1                TWI_11   8.421605
# 2              SLOPE_11   7.607044
# 3               LULC_11   5.824877
# 4               NDVI_11   5.584155
# 5             ASPECT_11   5.140273
# 6    PROXIMITY_ROADS_11   3.587255
# 7   PROXIMITY_RIVERS_11   2.892977
# 8       PROFILE_CURV_11   2.331462
# 9   PROXIMITY_FAULTS_11   2.327111
# 10         PLAN_CURV_11   2.266076
# 11               TRI_11   1.512336
#
# All remaining features above threshold are protected.

# %%
print(final_features_df.columns.tolist())
# Out:
# ['ASPECT_11', 'ELEVATION_11', 'SLOPE_11', 'PLAN_CURV_11', 'PROFILE_CURV_11', 'TWI_11', 'TRI_11', 'NDVI_11', 'LULC_11', 'PROXIMITY_ROADS_11', 'PROXIMITY_RIVERS_11', 'PROXIMITY_FAULTS_11']

# %%
# ============================================================
# FINAL FEATURES
# ============================================================

features = final_features_df.columns.tolist()

X = df[features]

y = df['label']

# %%
# ============================================================
# CREATE SPATIAL BLOCKS
# ============================================================

block_size = 5000   # 5 km

df['x_block'] = (
    df['X_COORD'] // block_size
).astype(int)

df['y_block'] = (
    df['Y_COORD'] // block_size
).astype(int)

df['spatial_block'] = (
    df['x_block'].astype(str)
    + "_"
    + df['y_block'].astype(str)
)

print(
    "\nTotal Spatial Blocks:",
    df['spatial_block'].nunique()
)
# Out:
# Total Spatial Blocks: 1806

# %%
from sklearn.model_selection import (
    GroupKFold,
    cross_validate,
    RandomizedSearchCV
)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve
)

import matplotlib.pyplot as plt

# %%
groups = df['spatial_block']
gkf = GroupKFold(n_splits=5)

# %%
X.columns.tolist()
# Out:
# ['ASPECT_11',
#  'ELEVATION_11',
#  'SLOPE_11',
#  'PLAN_CURV_11',
#  'PROFILE_CURV_11',
#  'TWI_11',
#  'TRI_11',
#  'NDVI_11',
#  'LULC_11',
#  'PROXIMITY_ROADS_11',
#  'PROXIMITY_RIVERS_11',
#  'PROXIMITY_FAULTS_11']

# %%
models = {

    "Logistic Regression": Pipeline([

        ('scaler', StandardScaler()),

        ('model', LogisticRegression(
            max_iter=1000,
            random_state=42,
            class_weight='balanced'
        ))
    ]),

    "Random Forest": RandomForestClassifier(
        random_state=42,
        class_weight='balanced'
    ),

    "Support Vector Machine": Pipeline([

        ('scaler', StandardScaler()),

        ('model', SVC(
            probability=True,
            random_state=42,
            class_weight='balanced'
        ))
    ]),

    "XGBoost": XGBClassifier(
        random_state=42,
        eval_metric='logloss'
    )
}

# %%
scoring = {
  'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'roc_auc': 'roc_auc'
}

# %%
#  ============================================================
# BASELINE SPATIAL CROSS VALIDATION
# ============================================================

print("\n" + "="*60)
print("BASELINE SPATIAL CROSS VALIDATION")
print("="*60)

results = []

for name, model in models.items():
    print("\n" + "="*60)
    print(f"MODEL: {name}")
    print("="*60)

    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []
    auc_scores = []
    plt.figure(figsize=(8,6))

    for fold, (train_idx, test_idx) in enumerate(
        gkf.split(X, y, groups)
    ):

        X_train = X.iloc[train_idx]
        X_test = X.iloc[test_idx]
        y_train = y.iloc[train_idx]
        y_test = y.iloc[test_idx]

        # ====================================================
        # TRAIN MODEL
        # ====================================================

        model.fit(X_train, y_train)

        # ====================================================
        # PREDICTIONS
        # ====================================================

        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]

        # ====================================================
        # METRICS
        # ====================================================

        accuracy_scores.append(
            accuracy_score(y_test, y_pred)
        )

        precision_scores.append(
            precision_score(y_test, y_pred)
        )

        recall_scores.append(
            recall_score(y_test, y_pred)
        )

        f1_scores.append(
            f1_score(y_test, y_pred)
        )

        auc = roc_auc_score(y_test, y_prob)

        auc_scores.append(auc)

        # ====================================================
        # ROC CURVE
        # ====================================================

        fpr, tpr, _ = roc_curve(y_test, y_prob)

        plt.plot(
            fpr,
            tpr,
            lw=2,
            label=f'Fold {fold+1} (AUC = {auc:.3f})'
        )

    # ========================================================
    # FINAL METRICS
    # ========================================================

    accuracy = np.mean(accuracy_scores)
    precision = np.mean(precision_scores)
    recall = np.mean(recall_scores)
    f1 = np.mean(f1_scores)
    auc_mean = np.mean(auc_scores)
    auc_std = np.std(auc_scores)

    print(f"Accuracy : {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1 Score : {f1:.4f}")
    print(f"ROC-AUC  : {auc_mean:.4f}")
    print(f"ROC STD  : {auc_std:.4f}")
    print("\nFold ROC Scores:")
    print(np.round(auc_scores, 4))

    # ========================================================
    # ROC PLOT SETTINGS
    # ========================================================

    plt.plot(
        [0, 1],
        [0, 1],
        linestyle='--'
    )

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{name} - Spatial CV ROC Curves")
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

    # ========================================================
    # STORE RESULTS
    # ========================================================

    results.append({

        "Model": name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1_Score": f1,
        "ROC_AUC": auc_mean,
        "ROC_STD": auc_std
    })

# ============================================================
# FINAL RESULTS TABLE
# ============================================================

results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    by='ROC_AUC',
    ascending=False
)

print("\n" + "="*60)
print("FINAL BASELINE SPATIAL CV RESULTS")
print("="*60)
print(results_df)
# Out:
# ============================================================
# BASELINE SPATIAL CROSS VALIDATION
# ============================================================
#
# ============================================================
# MODEL: Logistic Regression
# ============================================================
# Accuracy : 0.8906
# Precision: 0.8642
# Recall   : 0.9355
# F1 Score : 0.8984
# ROC-AUC  : 0.9560
# ROC STD  : 0.0042
#
# Fold ROC Scores:
# [0.9515 0.9551 0.9529 0.9566 0.9636]
# ============================================================
# MODEL: Random Forest
# ============================================================
# Accuracy : 0.9297
# Precision: 0.9645
# Recall   : 0.8969
# F1 Score : 0.9294
# ROC-AUC  : 0.9786
# ROC STD  : 0.0036
#
# Fold ROC Scores:
# [0.9814 0.9772 0.9746 0.9758 0.9842]
# ============================================================
# MODEL: Support Vector Machine
# ============================================================
# Accuracy : 0.9068
# Precision: 0.8924
# Recall   : 0.9321
# F1 Score : 0.9118
# ROC-AUC  : 0.9645
# ROC STD  : 0.0042
#
# Fold ROC Scores:
# [0.964  0.9629 0.9626 0.9604 0.9725]
# ============================================================
# MODEL: XGBoost
# ============================================================
# Accuracy : 0.9262
# Precision: 0.9599
# Recall   : 0.8946
# F1 Score : 0.9260
# ROC-AUC  : 0.9786
# ROC STD  : 0.0025
#
# Fold ROC Scores:
# [0.9801 0.9775 0.9778 0.9751 0.9826]
# ============================================================
# FINAL BASELINE SPATIAL CV RESULTS
# ============================================================
#                     Model  Accuracy  Precision    Recall  F1_Score   ROC_AUC  \
# 1           Random Forest  0.929664   0.964524  0.896860  0.929396  0.978638
# 3                 XGBoost  0.926188   0.959875  0.894582  0.926025  0.978637
# 2  Support Vector Machine  0.906826   0.892440  0.932064  0.911813  0.964488
# 0     Logistic Regression  0.890614   0.864200  0.935498  0.898361  0.955964
#
#     ROC_STD
# 1  0.003618
# 3  0.002544
# 2  0.004180
# 0  0.004201

# %%
rf_param_grid = {
    'n_estimators': [200, 300, 500],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

# %%
rf = RandomForestClassifier(
    random_state=42,
    class_weight='balanced'
)

# %%
rf_random = RandomizedSearchCV(

    estimator=rf,
    param_distributions=rf_param_grid,
    n_iter=30,
    scoring='roc_auc',
    cv=gkf,
    random_state=42,
    verbose=2,
    n_jobs=-1
)

rf_random.fit(X, y, groups=groups)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=GroupKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=RandomForestClassifier(class_weight='balanced',
#                                                     random_state=42),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'bootstrap': [True],
#                                         'max_depth': [10, 20, None],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 300, 500]},
#                    random_state=42, scoring='roc_auc', verbose=2)

# %%
best_rf = rf_random.best_estimator_
print("\nBest RF Parameters:")
print(rf_random.best_params_)
# Out:
# Best RF Parameters:
# {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}

# %%
from rasterio.windows import Window

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
best_rf = RandomForestClassifier(
    n_estimators=200,
    min_samples_split=2,
    min_samples_leaf=4,
    max_features="sqrt",
    max_depth=20,
    bootstrap=True,
    random_state=42,
    n_jobs=-1
)

# %%
# ============================================================
# RF FINAL SPATIAL CV
# ============================================================

rf_cv_results = cross_validate(
    estimator=best_rf,
    X=X,
    y=y,
    groups=groups,
    cv=gkf,
    scoring=scoring,
    n_jobs=-1
)

# %%
print("\n" + "="*60)
print("FINAL RANDOM FOREST SPATIAL CV RESULTS")
print("="*60)
print(f"Accuracy : {rf_cv_results['test_accuracy'].mean():.4f}")
print(f"Precision: {rf_cv_results['test_precision'].mean():.4f}")
print(f"Recall   : {rf_cv_results['test_recall'].mean():.4f}")
print(f"F1 Score : {rf_cv_results['test_f1'].mean():.4f}")
print(f"ROC-AUC  : {rf_cv_results['test_roc_auc'].mean():.4f}")
print(f"ROC STD  : {rf_cv_results['test_roc_auc'].std():.4f}")
print("\nFold ROC Scores:")
print(np.round(rf_cv_results['test_roc_auc'], 4))

# print(f"Mean ROC-AUC: {rf_cv_results['test_roc_auc'].mean():.4f}")
# print(f"ROC STD     : {rf_cv_results['test_roc_auc'].std():.4f}")
# print("\nFold ROC Scores:")
# print(rf_cv_results['test_roc_auc'])
# Out:
# ============================================================
# FINAL RANDOM FOREST SPATIAL CV RESULTS
# ============================================================
# Accuracy : 0.9323
# Precision: 0.9579
# Recall   : 0.9088
# F1 Score : 0.9327
# ROC-AUC  : 0.9800
# ROC STD  : 0.0030
#
# Fold ROC Scores:
# [0.9815 0.9775 0.9773 0.9787 0.9853]

# %%
# ============================================================
# RF FEATURE IMPORTANCE
# ============================================================

best_rf.fit(X, y)
rf_importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': best_rf.feature_importances_
})

rf_importance_df = rf_importance_df.sort_values(
    by='Importance',
    ascending=False
)

print("\n" + "="*60)
print("RANDOM FOREST FEATURE IMPORTANCE")
print("="*60)
print(rf_importance_df)

plt.figure(figsize=(10,6))

plt.barh(
    rf_importance_df['Feature'],
    rf_importance_df['Importance']
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Random Forest Feature Importance")
plt.gca().invert_yaxis()
plt.show()
# Out:
# ============================================================
# RANDOM FOREST FEATURE IMPORTANCE
# ============================================================
#                 Feature  Importance
# 9    PROXIMITY_ROADS_11    0.441478
# 1          ELEVATION_11    0.240965
# 7               NDVI_11    0.072320
# 10  PROXIMITY_RIVERS_11    0.064156
# 8               LULC_11    0.039967
# 2              SLOPE_11    0.032535
# 6                TRI_11    0.029585
# 5                TWI_11    0.021524
# 11  PROXIMITY_FAULTS_11    0.018759
# 3          PLAN_CURV_11    0.016561
# 4       PROFILE_CURV_11    0.014669
# 0             ASPECT_11    0.007482

# %%
plt.figure(figsize=(8,6))

for fold, (train_idx, test_idx) in enumerate(
    gkf.split(X, y, groups)
):

    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]
    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    best_rf.fit(X_train, y_train)
    y_prob = best_rf.predict_proba(X_test)[:,1]
    auc = roc_auc_score(y_test, y_prob)
    fpr, tpr, _ = roc_curve(y_test, y_prob)

    plt.plot(
        fpr,
        tpr,
        lw=2,
        label=f'Fold {fold+1} (AUC = {auc:.3f})'
    )

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Tuned Random Forest - Spatial CV ROC Curves")
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
xgb_param_grid = {
    'n_estimators': [200, 300, 500],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0],
    'gamma': [0, 0.1, 0.3],
    'min_child_weight': [1, 3, 5]
}

# %%
xgb = XGBClassifier(
    random_state=42,
    eval_metric='logloss'
)

# %%
xgb_random = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=xgb_param_grid,
    n_iter=30,
    scoring='roc_auc',
    cv=gkf,
    random_state=42,
    verbose=2,
    n_jobs=-1
)

# %%
print("\n" + "="*60)
print("TUNING XGBOOST")
print("="*60)

xgb_random.fit(X, y, groups=groups)
best_xgb = xgb_random.best_estimator_

print("\nBest XGB Parameters:")
print(xgb_random.best_params_)
# Out:
# ============================================================
# TUNING XGBOOST
# ============================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
# Best XGB Parameters:
# {'subsample': 0.7, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 1.0}

# %%
best_xgb = XGBClassifier(
    subsample=0.7,
    n_estimators=200,
    min_child_weight=3,
    max_depth=5,
    learning_rate=0.05,
    gamma=0,
    colsample_bytree=1.0,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42,
    n_jobs=-1
)

# %%
xgb_cv_results = cross_validate(
    estimator=best_xgb,
    X=X,
    y=y,
    groups=groups,
    cv=gkf,
    scoring=scoring,
    n_jobs=-1
)

# %%
print("\n" + "="*60)
print("FINAL XGBOOST SPATIAL CV RESULTS")
print("="*60)
# print(f"Mean ROC-AUC: {xgb_cv_results['test_roc_auc'].mean():.4f}")
# print(f"ROC STD     : {xgb_cv_results['test_roc_auc'].std():.4f}")
# print("\nFold ROC Scores:")
# print(xgb_cv_results['test_roc_auc'])

print(f"Accuracy : {xgb_cv_results['test_accuracy'].mean():.4f}")
print(f"Precision: {xgb_cv_results['test_precision'].mean():.4f}")
print(f"Recall   : {xgb_cv_results['test_recall'].mean():.4f}")
print(f"F1 Score : {xgb_cv_results['test_f1'].mean():.4f}")
print(f"ROC-AUC  : {xgb_cv_results['test_roc_auc'].mean():.4f}")
print(f"ROC STD  : {xgb_cv_results['test_roc_auc'].std():.4f}")
print("\nFold ROC Scores:")
print(np.round(xgb_cv_results['test_roc_auc'], 4))
# Out:
# ============================================================
# FINAL XGBOOST SPATIAL CV RESULTS
# ============================================================
# Accuracy : 0.9351
# Precision: 0.9528
# Recall   : 0.9200
# F1 Score : 0.9360
# ROC-AUC  : 0.9814
# ROC STD  : 0.0023
#
# Fold ROC Scores:
# [0.9827 0.9799 0.9808 0.9786 0.9851]

# %%
# ============================================================
# XGB FEATURE IMPORTANCE
# ============================================================

best_xgb.fit(X, y)
xgb_importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': best_xgb.feature_importances_
})

xgb_importance_df = xgb_importance_df.sort_values(
    by='Importance',
    ascending=False
)

print("\n" + "="*60)
print("XGBOOST FEATURE IMPORTANCE")
print("="*60)
print(xgb_importance_df)

plt.figure(figsize=(10,6))
plt.barh(
    xgb_importance_df['Feature'],
    xgb_importance_df['Importance']
)
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("XGBoost Feature Importance")
plt.gca().invert_yaxis()
plt.show()
# Out:
# ============================================================
# XGBOOST FEATURE IMPORTANCE
# ============================================================
#                 Feature  Importance
# 9    PROXIMITY_ROADS_11    0.684633
# 1          ELEVATION_11    0.054853
# 2              SLOPE_11    0.047572
# 10  PROXIMITY_RIVERS_11    0.041845
# 8               LULC_11    0.036889
# 6                TRI_11    0.029170
# 5                TWI_11    0.020925
# 7               NDVI_11    0.019514
# 3          PLAN_CURV_11    0.018274
# 11  PROXIMITY_FAULTS_11    0.016953
# 0             ASPECT_11    0.014885
# 4       PROFILE_CURV_11    0.014487

# %%
# ============================================================
# XGBOOST ROC CURVES
# ============================================================

plt.figure(figsize=(8,6))

for fold, (train_idx, test_idx) in enumerate(
    gkf.split(X, y, groups)
):

    X_train = X.iloc[train_idx]

    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]

    y_test = y.iloc[test_idx]

    # ========================================================
    # TRAIN MODEL
    # ========================================================

    best_xgb.fit(X_train, y_train)

    # ========================================================
    # PREDICTION PROBABILITIES
    # ========================================================

    y_prob = best_xgb.predict_proba(X_test)[:,1]

    # ========================================================
    # ROC + AUC
    # ========================================================

    auc = roc_auc_score(y_test, y_prob)

    fpr, tpr, _ = roc_curve(y_test, y_prob)

    # ========================================================
    # PLOT
    # ========================================================

    plt.plot(
        fpr,
        tpr,
        lw=2,
        label=f'Fold {fold+1} (AUC = {auc:.3f})'
    )

# ============================================================
# RANDOM BASELINE
# ============================================================

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

# ============================================================
# LABELS
# ============================================================

plt.xlabel("False Positive Rate")

plt.ylabel("True Positive Rate")

plt.title("Tuned XGBoost - Spatial CV ROC Curves")

plt.legend(loc='lower right')

plt.grid(True)

plt.show()

# %%
best_rf.fit(X, y)
best_xgb.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
import rasterio

# %%
['ASPECT_11',
 'ELEVATION_11',
 'SLOPE_11',
 'PLAN_CURV_11',
 'PROFILE_CURV_11',
 'TRI_11',
 'NDVI_11',
 'LULC_11',
 'PROXIMITY_ROADS_11',
 'PROXIMITY_RIVERS_11',
 'PROXIMITY_FAULTS_11',
 'MAX_RAINFALL_11']
# Out:
# ['ASPECT_11',
#  'ELEVATION_11',
#  'SLOPE_11',
#  'PLAN_CURV_11',
#  'PROFILE_CURV_11',
#  'TRI_11',
#  'NDVI_11',
#  'LULC_11',
#  'PROXIMITY_ROADS_11',
#  'PROXIMITY_RIVERS_11',
#  'PROXIMITY_FAULTS_11',
#  'MAX_RAINFALL_11']

# %%
raster_path="/content/drive/MyDrive/cosesmic/layers/rasters/"

# %%
models = {
    "RF": best_rf,
    "XGB": best_xgb
}

# %%
raster_paths = {
    "Aspect": raster_path + "aligned_Aspect.tif",
    "Elevation": raster_path + "aligned_Elevation.tif",
    "Slope": raster_path + "aligned_Slope.tif",
    "Plan Curvature": raster_path + "aligned_Plan_Curvature.tif",
    "Profile Curvature": raster_path + "aligned_Profile_Curvature.tif",
    "TRI": raster_path + "aligned_TRI.tif",
    "NDVI": raster_path + "aligned_NDVI.tif",
    "LULC": raster_path + "aligned_LULC.tif",
    "Proximity_Road": raster_path + "aligned_Proximity_Road.tif",
    "Proximity_Rivers": raster_path + "aligned_Proximity_Rivers.tif",
    "Proximity_Faults": raster_path + "aligned_Proximity_Faults.tif",
    "Max_Rainfall":raster_path+"aligned_Max_Rainfall.tif"
}

# %%
# ==========================================
# 3. OPEN RASTERS
# ==========================================
srcs = {
    feature: rasterio.open(path)
    for feature, path in raster_paths.items()
}

# Reference raster

ref = list(srcs.values())[0]

meta = ref.meta.copy()

height = ref.height
width = ref.width

print(f"Raster dimensions: {height} x {width}")
# Out:
# Raster dimensions: 10765 x 11731

# %%
# ==========================================
# 4. OUTPUT SETTINGS
# ==========================================

meta.update(
    dtype=rasterio.float32,
    count=1,
    compress='lzw'
)

# %%
# ==========================================
# 5. CHUNK SIZE
# ==========================================

# Reduce if RAM crashes
# Increase if system is strong

chunk_size = 512

# %%
from rasterio.windows import Window

# %%
for feature, src in srcs.items():

    print(
        feature,
        src.width,
        src.height,
        src.crs,
        src.transform
    )
# Out:
# Aspect 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Elevation 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Slope 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Plan Curvature 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Profile Curvature 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# TRI 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# NDVI 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# LULC 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Proximity_Road 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Proximity_Rivers 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Proximity_Faults 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|
# Max_Rainfall 11731 10765 EPSG:32644 | 28.39, 0.00, 169717.46|
# | 0.00,-28.39, 3483550.17|
# | 0.00, 0.00, 1.00|

# %%
df_pixels.columns = X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8286/3302601764.py in <cell line: 0>()
# ----> 1 df_pixels.columns = X.columns
#
# NameError: name 'df_pixels' is not defined

# %%
print(df_pixels.columns.tolist())
print(X.columns.tolist())

# %%
# !ls /content/drive/MyDrive/cosesmic/maps/
# Out:
# drive  RF_susceptibility.tif  sample_data  XGB_susceptibility.tif

# %%
# ==========================================
# 6. GENERATE SUSCEPTIBILITY MAPS
# ==========================================

for model_name, model in models.items():

    print(f"\nGenerating {model_name} susceptibility map...")

    output_path = f"/content/drive/MyDrive/cosesmic/maps/{model_name}_fr_guided_susceptibility.tif"

    with rasterio.open(
        output_path,
        "w",
        **meta
    ) as dst:

        # ==================================
        # LOOP THROUGH WINDOWS
        # ==================================

        for row in range(0, height, chunk_size):

            for col in range(0, width, chunk_size):

                # Define raster window

                window = Window(
                    col,
                    row,
                    min(chunk_size, width - col),
                    min(chunk_size, height - row)
                )

                arrays = []

                # ==========================
                # READ CHUNK FROM EACH RASTER
                # ==========================

                for feature, src in srcs.items():

                    arr = src.read(1, window=window,masked=True).filled(np.nan)

                    arrays.append(arr)

                # ==========================
                # STACK CHUNK
                # ==========================

                stack = np.stack(arrays, axis=-1)

                rows, cols, bands = stack.shape

                # ==========================
                # FLATTEN PIXELS
                # ==========================

                flat_pixels = stack.reshape(
                    rows * cols,
                    bands
                )

                # ==========================
                # CREATE DATAFRAME
                # ==========================

                df_pixels = pd.DataFrame(
                    flat_pixels,
                    columns=X.columns
                )

                # ==========================
                # HANDLE NAN VALUES
                # ==========================

                mask = np.any(
                  np.isnan(flat_pixels),
                  axis=1
                )

                valid_pixels = df_pixels[~mask]

                # Empty prediction array

                predictions = np.full(
                    rows * cols,
                    np.nan,
                    dtype=np.float32
                )

                # ==========================
                # PREDICT ONLY VALID PIXELS
                # ==========================

                if len(valid_pixels) > 0:

                    probs = model.predict_proba(
                        valid_pixels
                    )[:, 1]

                    predictions[~mask] = probs

                # ==================================
                # APPLY SLOPE MASKING
                # ==================================

                # IMPORTANT:
                # Use your actual slope raster key

                slope_arr = srcs["Slope"].read(
                    1,
                    window=window
                )

                # ==========================
                # RESHAPE BACK TO RASTER
                # ==========================

                predictions = predictions.reshape(
                    rows,
                    cols
                )

                # ==========================
                # APPLY SLOPE MASK
                # ==========================

                predictions[
                    slope_arr < 0.0872665
                ] = np.nan

                # ==========================
                # WRITE WINDOW TO OUTPUT
                # ==========================

                dst.write(
                    predictions.astype(
                        rasterio.float32
                    ),
                    1,
                    window=window
                )

                print(
                    f"{model_name} -> row {row}, col {col}"
                )

    print(f"\nSaved: {output_path}")
# Out:
# Generating RF susceptibility map...
# RF -> row 0, col 0
# RF -> row 0, col 512
# RF -> row 0, col 1024
# RF -> row 0, col 1536
# RF -> row 0, col 2048
# RF -> row 0, col 2560
# RF -> row 0, col 3072
# RF -> row 0, col 3584
# RF -> row 0, col 4096
# RF -> row 0, col 4608
# RF -> row 0, col 5120
# RF -> row 0, col 5632
# RF -> row 0, col 6144
# RF -> row 0, col 6656
# RF -> row 0, col 7168
# RF -> row 0, col 7680
# RF -> row 0, col 8192
# RF -> row 0, col 8704
# RF -> row 0, col 9216
# RF -> row 0, col 9728
# RF -> row 0, col 10240
# RF -> row 0, col 10752
# RF -> row 0, col 11264
# RF -> row 512, col 0
# RF -> row 512, col 512
# RF -> row 512, col 1024
# RF -> row 512, col 1536
# RF -> row 512, col 2048
# RF -> row 512, col 2560
# RF -> row 512, col 3072
# RF -> row 512, col 3584
# RF -> row 512, col 4096
# RF -> row 512, col 4608
# RF -> row 512, col 5120
# RF -> row 512, col 5632
# RF -> row 512, col 6144
# RF -> row 512, col 6656
# RF -> row 512, col 7168
# RF -> row 512, col 7680
# RF -> row 512, col 8192
# RF -> row 512, col 8704
# RF -> row 512, col 9216
# RF -> row 512, col 9728
# RF -> row 512, col 10240
# RF -> row 512, col 10752
# RF -> row 512, col 11264
# RF -> row 1024, col 0
# RF -> row 1024, col 512
# RF -> row 1024, col 1024
# RF -> row 1024, col 1536
# RF -> row 1024, col 2048
# RF -> row 1024, col 2560
# RF -> row 1024, col 3072
# RF -> row 1024, col 3584
# RF -> row 1024, col 4096
# RF -> row 1024, col 4608
# RF -> row 1024, col 5120
# RF -> row 1024, col 5632
# RF -> row 1024, col 6144
# RF -> row 1024, col 6656
# RF -> row 1024, col 7168
# RF -> row 1024, col 7680
# RF -> row 1024, col 8192
# RF -> row 1024, col 8704
# RF -> row 1024, col 9216
# RF -> row 1024, col 9728
# RF -> row 1024, col 10240
# RF -> row 1024, col 10752
# RF -> row 1024, col 11264
# RF -> row 1536, col 0
# RF -> row 1536, col 512
# RF -> row 1536, col 1024
# RF -> row 1536, col 1536
# RF -> row 1536, col 2048
# RF -> row 1536, col 2560
# RF -> row 1536, col 3072
# RF -> row 1536, col 3584
# RF -> row 1536, col 4096
# RF -> row 1536, col 4608
# RF -> row 1536, col 5120
# RF -> row 1536, col 5632
# RF -> row 1536, col 6144
# RF -> row 1536, col 6656
# RF -> row 1536, col 7168
# RF -> row 1536, col 7680
# RF -> row 1536, col 8192
# RF -> row 1536, col 8704
# RF -> row 1536, col 9216
# RF -> row 1536, col 9728
# RF -> row 1536, col 10240
# RF -> row 1536, col 10752
# RF -> row 1536, col 11264
# RF -> row 2048, col 0
# RF -> row 2048, col 512
# RF -> row 2048, col 1024
# RF -> row 2048, col 1536
# RF -> row 2048, col 2048
# RF -> row 2048, col 2560
# RF -> row 2048, col 3072
# RF -> row 2048, col 3584
# RF -> row 2048, col 4096
# RF -> row 2048, col 4608
# RF -> row 2048, col 5120
# RF -> row 2048, col 5632
# RF -> row 2048, col 6144
# RF -> row 2048, col 6656
# RF -> row 2048, col 7168
# RF -> row 2048, col 7680
# RF -> row 2048, col 8192
# RF -> row 2048, col 8704
# RF -> row 2048, col 9216
# RF -> row 2048, col 9728
# RF -> row 2048, col 10240
# RF -> row 2048, col 10752
# RF -> row 2048, col 11264
# RF -> row 2560, col 0
# RF -> row 2560, col 512
# RF -> row 2560, col 1024
# RF -> row 2560, col 1536
# RF -> row 2560, col 2048
# RF -> row 2560, col 2560
# RF -> row 2560, col 3072
# RF -> row 2560, col 3584
# RF -> row 2560, col 4096
# RF -> row 2560, col 4608
# RF -> row 2560, col 5120
# RF -> row 2560, col 5632
# RF -> row 2560, col 6144
# RF -> row 2560, col 6656
# RF -> row 2560, col 7168
# RF -> row 2560, col 7680
# RF -> row 2560, col 8192
# RF -> row 2560, col 8704
# RF -> row 2560, col 9216
# RF -> row 2560, col 9728
# RF -> row 2560, col 10240
# RF -> row 2560, col 10752
# RF -> row 2560, col 11264
# RF -> row 3072, col 0
# RF -> row 3072, col 512
# RF -> row 3072, col 1024
# RF -> row 3072, col 1536
# RF -> row 3072, col 2048
# RF -> row 3072, col 2560
# RF -> row 3072, col 3072
# RF -> row 3072, col 3584
# RF -> row 3072, col 4096
# RF -> row 3072, col 4608
# RF -> row 3072, col 5120
# RF -> row 3072, col 5632
# RF -> row 3072, col 6144
# RF -> row 3072, col 6656
# RF -> row 3072, col 7168
# RF -> row 3072, col 7680
# RF -> row 3072, col 8192
# RF -> row 3072, col 8704
# RF -> row 3072, col 9216
# RF -> row 3072, col 9728
# RF -> row 3072, col 10240
# RF -> row 3072, col 10752
# RF -> row 3072, col 11264
# RF -> row 3584, col 0
# RF -> row 3584, col 512
# RF -> row 3584, col 1024
# RF -> row 3584, col 1536
# RF -> row 3584, col 2048
# RF -> row 3584, col 2560
# RF -> row 3584, col 3072
# RF -> row 3584, col 3584
# RF -> row 3584, col 4096
# RF -> row 3584, col 4608
# RF -> row 3584, col 5120
# RF -> row 3584, col 5632
# RF -> row 3584, col 6144
# RF -> row 3584, col 6656
# RF -> row 3584, col 7168
# RF -> row 3584, col 7680
# RF -> row 3584, col 8192
# RF -> row 3584, col 8704
# RF -> row 3584, col 9216
# RF -> row 3584, col 9728
# RF -> row 3584, col 10240
# RF -> row 3584, col 10752
# RF -> row 3584, col 11264
# RF -> row 4096, col 0
# RF -> row 4096, col 512
# RF -> row 4096, col 1024
# RF -> row 4096, col 1536
# RF -> row 4096, col 2048
# RF -> row 4096, col 2560
# RF -> row 4096, col 3072
# RF -> row 4096, col 3584
# RF -> row 4096, col 4096
# RF -> row 4096, col 4608
# RF -> row 4096, col 5120
# RF -> row 4096, col 5632
# RF -> row 4096, col 6144
# RF -> row 4096, col 6656
# RF -> row 4096, col 7168
# RF -> row 4096, col 7680
# RF -> row 4096, col 8192
# RF -> row 4096, col 8704
# RF -> row 4096, col 9216
# RF -> row 4096, col 9728
# RF -> row 4096, col 10240
# RF -> row 4096, col 10752
# RF -> row 4096, col 11264
# RF -> row 4608, col 0
# RF -> row 4608, col 512
# RF -> row 4608, col 1024
# RF -> row 4608, col 1536
# RF -> row 4608, col 2048
# RF -> row 4608, col 2560
# RF -> row 4608, col 3072
# RF -> row 4608, col 3584
# RF -> row 4608, col 4096
# RF -> row 4608, col 4608
# RF -> row 4608, col 5120
# RF -> row 4608, col 5632
# RF -> row 4608, col 6144
# RF -> row 4608, col 6656
# RF -> row 4608, col 7168
# RF -> row 4608, col 7680
# RF -> row 4608, col 8192
# RF -> row 4608, col 8704
# RF -> row 4608, col 9216
# RF -> row 4608, col 9728
# RF -> row 4608, col 10240
# RF -> row 4608, col 10752
# RF -> row 4608, col 11264
# RF -> row 5120, col 0
# RF -> row 5120, col 512
# RF -> row 5120, col 1024
# RF -> row 5120, col 1536
# RF -> row 5120, col 2048
# RF -> row 5120, col 2560
# RF -> row 5120, col 3072
# RF -> row 5120, col 3584
# RF -> row 5120, col 4096
# RF -> row 5120, col 4608
# RF -> row 5120, col 5120
# RF -> row 5120, col 5632
# RF -> row 5120, col 6144
# RF -> row 5120, col 6656
# RF -> row 5120, col 7168
# RF -> row 5120, col 7680
# RF -> row 5120, col 8192
# RF -> row 5120, col 8704
# RF -> row 5120, col 9216
# RF -> row 5120, col 9728
# RF -> row 5120, col 10240
# RF -> row 5120, col 10752
# RF -> row 5120, col 11264
# RF -> row 5632, col 0
# RF -> row 5632, col 512
# RF -> row 5632, col 1024
# RF -> row 5632, col 1536
# RF -> row 5632, col 2048
# RF -> row 5632, col 2560
# RF -> row 5632, col 3072
# RF -> row 5632, col 3584
# RF -> row 5632, col 4096
# RF -> row 5632, col 4608
# RF -> row 5632, col 5120
# RF -> row 5632, col 5632
# RF -> row 5632, col 6144
# RF -> row 5632, col 6656
# RF -> row 5632, col 7168
# RF -> row 5632, col 7680
# RF -> row 5632, col 8192
# RF -> row 5632, col 8704
# RF -> row 5632, col 9216
# RF -> row 5632, col 9728
# RF -> row 5632, col 10240
# RF -> row 5632, col 10752
# RF -> row 5632, col 11264
# RF -> row 6144, col 0
# RF -> row 6144, col 512
# RF -> row 6144, col 1024
# RF -> row 6144, col 1536
# RF -> row 6144, col 2048
# RF -> row 6144, col 2560
# RF -> row 6144, col 3072
# RF -> row 6144, col 3584
# RF -> row 6144, col 4096
# RF -> row 6144, col 4608
# RF -> row 6144, col 5120
# RF -> row 6144, col 5632
# RF -> row 6144, col 6144
# RF -> row 6144, col 6656
# RF -> row 6144, col 7168
# RF -> row 6144, col 7680
# RF -> row 6144, col 8192
# RF -> row 6144, col 8704
# RF -> row 6144, col 9216
# RF -> row 6144, col 9728
# RF -> row 6144, col 10240
# RF -> row 6144, col 10752
# RF -> row 6144, col 11264
# RF -> row 6656, col 0
# RF -> row 6656, col 512
# RF -> row 6656, col 1024
# RF -> row 6656, col 1536
# RF -> row 6656, col 2048
# RF -> row 6656, col 2560
# RF -> row 6656, col 3072
# RF -> row 6656, col 3584
# RF -> row 6656, col 4096
# RF -> row 6656, col 4608
# RF -> row 6656, col 5120
# RF -> row 6656, col 5632
# RF -> row 6656, col 6144
# RF -> row 6656, col 6656
# RF -> row 6656, col 7168
# RF -> row 6656, col 7680
# RF -> row 6656, col 8192
# RF -> row 6656, col 8704
# RF -> row 6656, col 9216
# RF -> row 6656, col 9728
# RF -> row 6656, col 10240
# RF -> row 6656, col 10752
# RF -> row 6656, col 11264
# RF -> row 7168, col 0
# RF -> row 7168, col 512
# RF -> row 7168, col 1024
# RF -> row 7168, col 1536
# RF -> row 7168, col 2048
# RF -> row 7168, col 2560
# RF -> row 7168, col 3072
# RF -> row 7168, col 3584
# RF -> row 7168, col 4096
# RF -> row 7168, col 4608
# RF -> row 7168, col 5120
# RF -> row 7168, col 5632
# RF -> row 7168, col 6144
# RF -> row 7168, col 6656
# RF -> row 7168, col 7168
# RF -> row 7168, col 7680
# RF -> row 7168, col 8192
# RF -> row 7168, col 8704
# RF -> row 7168, col 9216
# RF -> row 7168, col 9728
# RF -> row 7168, col 10240
# RF -> row 7168, col 10752
# RF -> row 7168, col 11264
# RF -> row 7680, col 0
# RF -> row 7680, col 512
# RF -> row 7680, col 1024
# RF -> row 7680, col 1536
# RF -> row 7680, col 2048
# RF -> row 7680, col 2560
# RF -> row 7680, col 3072
# RF -> row 7680, col 3584
# RF -> row 7680, col 4096
# RF -> row 7680, col 4608
# RF -> row 7680, col 5120
# RF -> row 7680, col 5632
# RF -> row 7680, col 6144
# RF -> row 7680, col 6656
# RF -> row 7680, col 7168
# RF -> row 7680, col 7680
# RF -> row 7680, col 8192
# RF -> row 7680, col 8704
# RF -> row 7680, col 9216
# RF -> row 7680, col 9728
# RF -> row 7680, col 10240
# RF -> row 7680, col 10752
# RF -> row 7680, col 11264
# RF -> row 8192, col 0
# RF -> row 8192, col 512
# RF -> row 8192, col 1024
# RF -> row 8192, col 1536
# RF -> row 8192, col 2048
# RF -> row 8192, col 2560
# RF -> row 8192, col 3072
# RF -> row 8192, col 3584
# RF -> row 8192, col 4096
# RF -> row 8192, col 4608
# RF -> row 8192, col 5120
# RF -> row 8192, col 5632
# RF -> row 8192, col 6144
# RF -> row 8192, col 6656
# RF -> row 8192, col 7168
# RF -> row 8192, col 7680
# RF -> row 8192, col 8192
# RF -> row 8192, col 8704
# RF -> row 8192, col 9216
# RF -> row 8192, col 9728
# RF -> row 8192, col 10240
# RF -> row 8192, col 10752
# RF -> row 8192, col 11264
# RF -> row 8704, col 0
# RF -> row 8704, col 512
# RF -> row 8704, col 1024
# RF -> row 8704, col 1536
# RF -> row 8704, col 2048
# RF -> row 8704, col 2560
# RF -> row 8704, col 3072
# RF -> row 8704, col 3584
# RF -> row 8704, col 4096
# RF -> row 8704, col 4608
# RF -> row 8704, col 5120
# RF -> row 8704, col 5632
# RF -> row 8704, col 6144
# RF -> row 8704, col 6656
# RF -> row 8704, col 7168
# RF -> row 8704, col 7680
# RF -> row 8704, col 8192
# RF -> row 8704, col 8704
# RF -> row 8704, col 9216
# RF -> row 8704, col 9728
# RF -> row 8704, col 10240
# RF -> row 8704, col 10752
# RF -> row 8704, col 11264
# RF -> row 9216, col 0
# RF -> row 9216, col 512
# RF -> row 9216, col 1024
# RF -> row 9216, col 1536
# RF -> row 9216, col 2048
# RF -> row 9216, col 2560
# RF -> row 9216, col 3072
# RF -> row 9216, col 3584
# RF -> row 9216, col 4096
# RF -> row 9216, col 4608
# RF -> row 9216, col 5120
# RF -> row 9216, col 5632
# RF -> row 9216, col 6144
# RF -> row 9216, col 6656
# RF -> row 9216, col 7168
# RF -> row 9216, col 7680
# RF -> row 9216, col 8192
# RF -> row 9216, col 8704
# RF -> row 9216, col 9216
# RF -> row 9216, col 9728
# RF -> row 9216, col 10240
# RF -> row 9216, col 10752
# RF -> row 9216, col 11264
# RF -> row 9728, col 0
# RF -> row 9728, col 512
# RF -> row 9728, col 1024
# RF -> row 9728, col 1536
# RF -> row 9728, col 2048
# RF -> row 9728, col 2560
# RF -> row 9728, col 3072
# RF -> row 9728, col 3584
# RF -> row 9728, col 4096
# RF -> row 9728, col 4608
# RF -> row 9728, col 5120
# RF -> row 9728, col 5632
# RF -> row 9728, col 6144
# RF -> row 9728, col 6656
# RF -> row 9728, col 7168
# RF -> row 9728, col 7680
# RF -> row 9728, col 8192
# RF -> row 9728, col 8704
# RF -> row 9728, col 9216
# RF -> row 9728, col 9728
# RF -> row 9728, col 10240
# RF -> row 9728, col 10752
# RF -> row 9728, col 11264
# RF -> row 10240, col 0
# RF -> row 10240, col 512
# RF -> row 10240, col 1024
# RF -> row 10240, col 1536
# RF -> row 10240, col 2048
# RF -> row 10240, col 2560
# RF -> row 10240, col 3072
# RF -> row 10240, col 3584
# RF -> row 10240, col 4096
# RF -> row 10240, col 4608
# RF -> row 10240, col 5120
# RF -> row 10240, col 5632
# RF -> row 10240, col 6144
# RF -> row 10240, col 6656
# RF -> row 10240, col 7168
# RF -> row 10240, col 7680
# RF -> row 10240, col 8192
# RF -> row 10240, col 8704
# RF -> row 10240, col 9216
# RF -> row 10240, col 9728
# RF -> row 10240, col 10240
# RF -> row 10240, col 10752
# RF -> row 10240, col 11264
# RF -> row 10752, col 0
# RF -> row 10752, col 512
# RF -> row 10752, col 1024
# RF -> row 10752, col 1536
# RF -> row 10752, col 2048
# RF -> row 10752, col 2560
# RF -> row 10752, col 3072
# RF -> row 10752, col 3584
# RF -> row 10752, col 4096
# RF -> row 10752, col 4608
# RF -> row 10752, col 5120
# RF -> row 10752, col 5632
# RF -> row 10752, col 6144
# RF -> row 10752, col 6656
# RF -> row 10752, col 7168
# RF -> row 10752, col 7680
# RF -> row 10752, col 8192
# RF -> row 10752, col 8704
# RF -> row 10752, col 9216
# RF -> row 10752, col 9728
# RF -> row 10752, col 10240
# RF -> row 10752, col 10752
# RF -> row 10752, col 11264
#
# Saved: /content/drive/MyDrive/cosesmic/maps/RF_fr_guided_susceptibility.tif
#
# Generating XGB susceptibility map...
# XGB -> row 0, col 0
# XGB -> row 0, col 512
# XGB -> row 0, col 1024
# XGB -> row 0, col 1536
# XGB -> row 0, col 2048
# XGB -> row 0, col 2560
# XGB -> row 0, col 3072
# XGB -> row 0, col 3584
# XGB -> row 0, col 4096
# XGB -> row 0, col 4608
# XGB -> row 0, col 5120
# XGB -> row 0, col 5632
# XGB -> row 0, col 6144
# XGB -> row 0, col 6656
# XGB -> row 0, col 7168
# XGB -> row 0, col 7680
# XGB -> row 0, col 8192
# XGB -> row 0, col 8704
# XGB -> row 0, col 9216
# XGB -> row 0, col 9728
# XGB -> row 0, col 10240
# XGB -> row 0, col 10752
# XGB -> row 0, col 11264
# XGB -> row 512, col 0
# XGB -> row 512, col 512
# XGB -> row 512, col 1024
# XGB -> row 512, col 1536
# XGB -> row 512, col 2048
# XGB -> row 512, col 2560
# XGB -> row 512, col 3072
# XGB -> row 512, col 3584
# XGB -> row 512, col 4096
# XGB -> row 512, col 4608
# XGB -> row 512, col 5120
# XGB -> row 512, col 5632
# XGB -> row 512, col 6144
# XGB -> row 512, col 6656
# XGB -> row 512, col 7168
# XGB -> row 512, col 7680
# XGB -> row 512, col 8192
# XGB -> row 512, col 8704
# XGB -> row 512, col 9216
# XGB -> row 512, col 9728
# XGB -> row 512, col 10240
# XGB -> row 512, col 10752
# XGB -> row 512, col 11264
# XGB -> row 1024, col 0
# XGB -> row 1024, col 512
# XGB -> row 1024, col 1024
# XGB -> row 1024, col 1536
# XGB -> row 1024, col 2048
# XGB -> row 1024, col 2560
# XGB -> row 1024, col 3072
# XGB -> row 1024, col 3584
# XGB -> row 1024, col 4096
# XGB -> row 1024, col 4608
# XGB -> row 1024, col 5120
# XGB -> row 1024, col 5632
# XGB -> row 1024, col 6144
# XGB -> row 1024, col 6656
# XGB -> row 1024, col 7168
# XGB -> row 1024, col 7680
# XGB -> row 1024, col 8192
# XGB -> row 1024, col 8704
# XGB -> row 1024, col 9216
# XGB -> row 1024, col 9728
# XGB -> row 1024, col 10240
# XGB -> row 1024, col 10752
# XGB -> row 1024, col 11264
# XGB -> row 1536, col 0
# XGB -> row 1536, col 512
# XGB -> row 1536, col 1024
# XGB -> row 1536, col 1536
# XGB -> row 1536, col 2048
# XGB -> row 1536, col 2560
# XGB -> row 1536, col 3072
# XGB -> row 1536, col 3584
# XGB -> row 1536, col 4096
# XGB -> row 1536, col 4608
# XGB -> row 1536, col 5120
# XGB -> row 1536, col 5632
# XGB -> row 1536, col 6144
# XGB -> row 1536, col 6656
# XGB -> row 1536, col 7168
# XGB -> row 1536, col 7680
# XGB -> row 1536, col 8192
# XGB -> row 1536, col 8704
# XGB -> row 1536, col 9216
# XGB -> row 1536, col 9728
# XGB -> row 1536, col 10240
# XGB -> row 1536, col 10752
# XGB -> row 1536, col 11264
# XGB -> row 2048, col 0
# XGB -> row 2048, col 512
# XGB -> row 2048, col 1024
# XGB -> row 2048, col 1536
# XGB -> row 2048, col 2048
# XGB -> row 2048, col 2560
# XGB -> row 2048, col 3072
# XGB -> row 2048, col 3584
# XGB -> row 2048, col 4096
# XGB -> row 2048, col 4608
# XGB -> row 2048, col 5120
# XGB -> row 2048, col 5632
# XGB -> row 2048, col 6144
# XGB -> row 2048, col 6656
# XGB -> row 2048, col 7168
# XGB -> row 2048, col 7680
# XGB -> row 2048, col 8192
# XGB -> row 2048, col 8704
# XGB -> row 2048, col 9216
# XGB -> row 2048, col 9728
# XGB -> row 2048, col 10240
# XGB -> row 2048, col 10752
# XGB -> row 2048, col 11264
# XGB -> row 2560, col 0
# XGB -> row 2560, col 512
# XGB -> row 2560, col 1024
# XGB -> row 2560, col 1536
# XGB -> row 2560, col 2048
# XGB -> row 2560, col 2560
# XGB -> row 2560, col 3072
# XGB -> row 2560, col 3584
# XGB -> row 2560, col 4096
# XGB -> row 2560, col 4608
# XGB -> row 2560, col 5120
# XGB -> row 2560, col 5632
# XGB -> row 2560, col 6144
# XGB -> row 2560, col 6656
# XGB -> row 2560, col 7168
# XGB -> row 2560, col 7680
# XGB -> row 2560, col 8192
# XGB -> row 2560, col 8704
# XGB -> row 2560, col 9216
# XGB -> row 2560, col 9728
# XGB -> row 2560, col 10240
# XGB -> row 2560, col 10752
# XGB -> row 2560, col 11264
# XGB -> row 3072, col 0
# XGB -> row 3072, col 512
# XGB -> row 3072, col 1024
# XGB -> row 3072, col 1536
# XGB -> row 3072, col 2048
# XGB -> row 3072, col 2560
# XGB -> row 3072, col 3072
# XGB -> row 3072, col 3584
# XGB -> row 3072, col 4096
# XGB -> row 3072, col 4608
# XGB -> row 3072, col 5120
# XGB -> row 3072, col 5632
# XGB -> row 3072, col 6144
# XGB -> row 3072, col 6656
# XGB -> row 3072, col 7168
# XGB -> row 3072, col 7680
# XGB -> row 3072, col 8192
# XGB -> row 3072, col 8704
# XGB -> row 3072, col 9216
# XGB -> row 3072, col 9728
# XGB -> row 3072, col 10240
# XGB -> row 3072, col 10752
# XGB -> row 3072, col 11264
# XGB -> row 3584, col 0
# XGB -> row 3584, col 512
# XGB -> row 3584, col 1024
# XGB -> row 3584, col 1536
# XGB -> row 3584, col 2048
# XGB -> row 3584, col 2560
# XGB -> row 3584, col 3072
# XGB -> row 3584, col 3584
# XGB -> row 3584, col 4096
# XGB -> row 3584, col 4608
# XGB -> row 3584, col 5120
# XGB -> row 3584, col 5632
# XGB -> row 3584, col 6144
# XGB -> row 3584, col 6656
# XGB -> row 3584, col 7168
# XGB -> row 3584, col 7680
# XGB -> row 3584, col 8192
# XGB -> row 3584, col 8704
# XGB -> row 3584, col 9216
# XGB -> row 3584, col 9728
# XGB -> row 3584, col 10240
# XGB -> row 3584, col 10752
# XGB -> row 3584, col 11264
# XGB -> row 4096, col 0
# XGB -> row 4096, col 512
# XGB -> row 4096, col 1024
# XGB -> row 4096, col 1536
# XGB -> row 4096, col 2048
# XGB -> row 4096, col 2560
# XGB -> row 4096, col 3072
# XGB -> row 4096, col 3584
# XGB -> row 4096, col 4096
# XGB -> row 4096, col 4608
# XGB -> row 4096, col 5120
# XGB -> row 4096, col 5632
# XGB -> row 4096, col 6144
# XGB -> row 4096, col 6656
# XGB -> row 4096, col 7168
# XGB -> row 4096, col 7680
# XGB -> row 4096, col 8192
# XGB -> row 4096, col 8704
# XGB -> row 4096, col 9216
# XGB -> row 4096, col 9728
# XGB -> row 4096, col 10240
# XGB -> row 4096, col 10752
# XGB -> row 4096, col 11264
# XGB -> row 4608, col 0
# XGB -> row 4608, col 512
# XGB -> row 4608, col 1024
# XGB -> row 4608, col 1536
# XGB -> row 4608, col 2048
# XGB -> row 4608, col 2560
# XGB -> row 4608, col 3072
# XGB -> row 4608, col 3584
# XGB -> row 4608, col 4096
# XGB -> row 4608, col 4608
# XGB -> row 4608, col 5120
# XGB -> row 4608, col 5632
# XGB -> row 4608, col 6144
# XGB -> row 4608, col 6656
# XGB -> row 4608, col 7168
# XGB -> row 4608, col 7680
# XGB -> row 4608, col 8192
# XGB -> row 4608, col 8704
# XGB -> row 4608, col 9216
# XGB -> row 4608, col 9728
# XGB -> row 4608, col 10240
# XGB -> row 4608, col 10752
# XGB -> row 4608, col 11264
# XGB -> row 5120, col 0
# XGB -> row 5120, col 512
# XGB -> row 5120, col 1024
# XGB -> row 5120, col 1536
# XGB -> row 5120, col 2048
# XGB -> row 5120, col 2560
# XGB -> row 5120, col 3072
# XGB -> row 5120, col 3584
# XGB -> row 5120, col 4096
# XGB -> row 5120, col 4608
# XGB -> row 5120, col 5120
# XGB -> row 5120, col 5632
# XGB -> row 5120, col 6144
# XGB -> row 5120, col 6656
# XGB -> row 5120, col 7168
# XGB -> row 5120, col 7680
# XGB -> row 5120, col 8192
# XGB -> row 5120, col 8704
# XGB -> row 5120, col 9216
# XGB -> row 5120, col 9728
# XGB -> row 5120, col 10240
# XGB -> row 5120, col 10752
# XGB -> row 5120, col 11264
# XGB -> row 5632, col 0
# XGB -> row 5632, col 512
# XGB -> row 5632, col 1024
# XGB -> row 5632, col 1536
# XGB -> row 5632, col 2048
# XGB -> row 5632, col 2560
# XGB -> row 5632, col 3072
# XGB -> row 5632, col 3584
# XGB -> row 5632, col 4096
# XGB -> row 5632, col 4608
# XGB -> row 5632, col 5120
# XGB -> row 5632, col 5632
# XGB -> row 5632, col 6144
# XGB -> row 5632, col 6656
# XGB -> row 5632, col 7168
# XGB -> row 5632, col 7680
# XGB -> row 5632, col 8192
# XGB -> row 5632, col 8704
# XGB -> row 5632, col 9216
# XGB -> row 5632, col 9728
# XGB -> row 5632, col 10240
# XGB -> row 5632, col 10752
# XGB -> row 5632, col 11264
# XGB -> row 6144, col 0
# XGB -> row 6144, col 512
# XGB -> row 6144, col 1024
# XGB -> row 6144, col 1536
# XGB -> row 6144, col 2048
# XGB -> row 6144, col 2560
# XGB -> row 6144, col 3072
# XGB -> row 6144, col 3584
# XGB -> row 6144, col 4096
# XGB -> row 6144, col 4608
# XGB -> row 6144, col 5120
# XGB -> row 6144, col 5632
# XGB -> row 6144, col 6144
# XGB -> row 6144, col 6656
# XGB -> row 6144, col 7168
# XGB -> row 6144, col 7680
# XGB -> row 6144, col 8192
# XGB -> row 6144, col 8704
# XGB -> row 6144, col 9216
# XGB -> row 6144, col 9728
# XGB -> row 6144, col 10240
# XGB -> row 6144, col 10752
# XGB -> row 6144, col 11264
# XGB -> row 6656, col 0
# XGB -> row 6656, col 512
# XGB -> row 6656, col 1024
# XGB -> row 6656, col 1536
# XGB -> row 6656, col 2048
# XGB -> row 6656, col 2560
# XGB -> row 6656, col 3072
# XGB -> row 6656, col 3584
# XGB -> row 6656, col 4096
# XGB -> row 6656, col 4608
# XGB -> row 6656, col 5120
# XGB -> row 6656, col 5632
# XGB -> row 6656, col 6144
# XGB -> row 6656, col 6656
# XGB -> row 6656, col 7168
# XGB -> row 6656, col 7680
# XGB -> row 6656, col 8192
# XGB -> row 6656, col 8704
# XGB -> row 6656, col 9216
# XGB -> row 6656, col 9728
# XGB -> row 6656, col 10240
# XGB -> row 6656, col 10752
# XGB -> row 6656, col 11264
# XGB -> row 7168, col 0
# XGB -> row 7168, col 512
# XGB -> row 7168, col 1024
# XGB -> row 7168, col 1536
# XGB -> row 7168, col 2048
# XGB -> row 7168, col 2560
# XGB -> row 7168, col 3072
# XGB -> row 7168, col 3584
# XGB -> row 7168, col 4096
# XGB -> row 7168, col 4608
# XGB -> row 7168, col 5120
# XGB -> row 7168, col 5632
# XGB -> row 7168, col 6144
# XGB -> row 7168, col 6656
# XGB -> row 7168, col 7168
# XGB -> row 7168, col 7680
# XGB -> row 7168, col 8192
# XGB -> row 7168, col 8704
# XGB -> row 7168, col 9216
# XGB -> row 7168, col 9728
# XGB -> row 7168, col 10240
# XGB -> row 7168, col 10752
# XGB -> row 7168, col 11264
# XGB -> row 7680, col 0
# XGB -> row 7680, col 512
# XGB -> row 7680, col 1024
# XGB -> row 7680, col 1536
# XGB -> row 7680, col 2048
# XGB -> row 7680, col 2560
# XGB -> row 7680, col 3072
# XGB -> row 7680, col 3584
# XGB -> row 7680, col 4096
# XGB -> row 7680, col 4608
# XGB -> row 7680, col 5120
# XGB -> row 7680, col 5632
# XGB -> row 7680, col 6144
# XGB -> row 7680, col 6656
# XGB -> row 7680, col 7168
# XGB -> row 7680, col 7680
# XGB -> row 7680, col 8192
# XGB -> row 7680, col 8704
# XGB -> row 7680, col 9216
# XGB -> row 7680, col 9728
# XGB -> row 7680, col 10240
# XGB -> row 7680, col 10752
# XGB -> row 7680, col 11264
# XGB -> row 8192, col 0
# XGB -> row 8192, col 512
# XGB -> row 8192, col 1024
# XGB -> row 8192, col 1536
# XGB -> row 8192, col 2048
# XGB -> row 8192, col 2560
# XGB -> row 8192, col 3072
# XGB -> row 8192, col 3584
# XGB -> row 8192, col 4096
# XGB -> row 8192, col 4608
# XGB -> row 8192, col 5120
# XGB -> row 8192, col 5632
# XGB -> row 8192, col 6144
# XGB -> row 8192, col 6656
# XGB -> row 8192, col 7168
# XGB -> row 8192, col 7680
# XGB -> row 8192, col 8192
# XGB -> row 8192, col 8704
# XGB -> row 8192, col 9216
# XGB -> row 8192, col 9728
# XGB -> row 8192, col 10240
# XGB -> row 8192, col 10752
# XGB -> row 8192, col 11264
# XGB -> row 8704, col 0
# XGB -> row 8704, col 512
# XGB -> row 8704, col 1024
# XGB -> row 8704, col 1536
# XGB -> row 8704, col 2048
# XGB -> row 8704, col 2560
# XGB -> row 8704, col 3072
# XGB -> row 8704, col 3584
# XGB -> row 8704, col 4096
# XGB -> row 8704, col 4608
# XGB -> row 8704, col 5120
# XGB -> row 8704, col 5632
# XGB -> row 8704, col 6144
# XGB -> row 8704, col 6656
# XGB -> row 8704, col 7168
# XGB -> row 8704, col 7680
# XGB -> row 8704, col 8192
# XGB -> row 8704, col 8704
# XGB -> row 8704, col 9216
# XGB -> row 8704, col 9728
# XGB -> row 8704, col 10240
# XGB -> row 8704, col 10752
# XGB -> row 8704, col 11264
# XGB -> row 9216, col 0
# XGB -> row 9216, col 512
# XGB -> row 9216, col 1024
# XGB -> row 9216, col 1536
# XGB -> row 9216, col 2048
# XGB -> row 9216, col 2560
# XGB -> row 9216, col 3072
# XGB -> row 9216, col 3584
# XGB -> row 9216, col 4096
# XGB -> row 9216, col 4608
# XGB -> row 9216, col 5120
# XGB -> row 9216, col 5632
# XGB -> row 9216, col 6144
# XGB -> row 9216, col 6656
# XGB -> row 9216, col 7168
# XGB -> row 9216, col 7680
# XGB -> row 9216, col 8192
# XGB -> row 9216, col 8704
# XGB -> row 9216, col 9216
# XGB -> row 9216, col 9728
# XGB -> row 9216, col 10240
# XGB -> row 9216, col 10752
# XGB -> row 9216, col 11264
# XGB -> row 9728, col 0
# XGB -> row 9728, col 512
# XGB -> row 9728, col 1024
# XGB -> row 9728, col 1536
# XGB -> row 9728, col 2048
# XGB -> row 9728, col 2560
# XGB -> row 9728, col 3072
# XGB -> row 9728, col 3584
# XGB -> row 9728, col 4096
# XGB -> row 9728, col 4608
# XGB -> row 9728, col 5120
# XGB -> row 9728, col 5632
# XGB -> row 9728, col 6144
# XGB -> row 9728, col 6656
# XGB -> row 9728, col 7168
# XGB -> row 9728, col 7680
# XGB -> row 9728, col 8192
# XGB -> row 9728, col 8704
# XGB -> row 9728, col 9216
# XGB -> row 9728, col 9728
# XGB -> row 9728, col 10240
# XGB -> row 9728, col 10752
# XGB -> row 9728, col 11264
# XGB -> row 10240, col 0
# XGB -> row 10240, col 512
# XGB -> row 10240, col 1024
# XGB -> row 10240, col 1536
# XGB -> row 10240, col 2048
# XGB -> row 10240, col 2560
# XGB -> row 10240, col 3072
# XGB -> row 10240, col 3584
# XGB -> row 10240, col 4096
# XGB -> row 10240, col 4608
# XGB -> row 10240, col 5120
# XGB -> row 10240, col 5632
# XGB -> row 10240, col 6144
# XGB -> row 10240, col 6656
# XGB -> row 10240, col 7168
# XGB -> row 10240, col 7680
# XGB -> row 10240, col 8192
# XGB -> row 10240, col 8704
# XGB -> row 10240, col 9216
# XGB -> row 10240, col 9728
# XGB -> row 10240, col 10240
# XGB -> row 10240, col 10752
# XGB -> row 10240, col 11264
# XGB -> row 10752, col 0
# XGB -> row 10752, col 512
# XGB -> row 10752, col 1024
# XGB -> row 10752, col 1536
# XGB -> row 10752, col 2048
# XGB -> row 10752, col 2560
# XGB -> row 10752, col 3072
# XGB -> row 10752, col 3584
# XGB -> row 10752, col 4096
# XGB -> row 10752, col 4608
# XGB -> row 10752, col 5120
# XGB -> row 10752, col 5632
# XGB -> row 10752, col 6144
# XGB -> row 10752, col 6656
# XGB -> row 10752, col 7168
# XGB -> row 10752, col 7680
# XGB -> row 10752, col 8192
# XGB -> row 10752, col 8704
# XGB -> row 10752, col 9216
# XGB -> row 10752, col 9728
# XGB -> row 10752, col 10240
# XGB -> row 10752, col 10752
# XGB -> row 10752, col 11264
#
# Saved: /content/drive/MyDrive/cosesmic/maps/XGB_fr_guided_susceptibility.tif

# %%
print(
    "Prediction stats:",
    np.nanmin(predictions),
    np.nanmax(predictions),
    np.nanmean(predictions)
)
# Out:
# Prediction stats: nan nan nan
# /tmp/ipykernel_2726/1616876306.py:3: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(predictions),
# /tmp/ipykernel_2726/1616876306.py:4: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(predictions),
# /tmp/ipykernel_2726/1616876306.py:5: RuntimeWarning: Mean of empty slice
#   np.nanmean(predictions)

# %%
arr = srcs["Slope"].read(
    1,
    masked=True
).filled(np.nan)

valid = arr[~np.isnan(arr)]

print("MIN:", valid.min())
print("MAX:", valid.max())
print("MEAN:", valid.mean())
# Out:
# MIN: 0.0
# MAX: 1.5646517
# MEAN: 0.41501117

# %%
print("Total:", len(df_pixels))
print("Valid:", len(valid_pixels))
# Out:
# Total: 6071
# Valid: 6071

# %%
print(
    "Probabilities:",
    np.min(probs),
    np.max(probs)
)
# Out:
# Probabilities: 0.9526211 0.9526211

# %%
print(list(srcs.keys()))
print(list(X.columns))
# Out:
# ['Aspect', 'Elevation', 'Slope', 'Plan Curvature', 'Profile Curvature', 'TRI', 'NDVI', 'LULC', 'Proximity_Road', 'Proximity_Rivers', 'Proximity_Faults', 'Max_Rainfall']
# ['ASPECT_11', 'ELEVATION_11', 'SLOPE_11', 'PLAN_CURV_11', 'PROFILE_CURV_11', 'TWI_11', 'TRI_11', 'NDVI_11', 'LULC_11', 'PROXIMITY_ROADS_11', 'PROXIMITY_RIVERS_11', 'PROXIMITY_FAULTS_11']

# %%
for i, feature in enumerate(srcs.keys()):

    print(
        feature,
        np.nanmin(arrays[i]),
        np.nanmax(arrays[i])
    )
# Out:
# Aspect -99999.0 -99999.0
# Elevation -99999.0 -99999.0
# Slope -99999.0 -99999.0
# Plan Curvature -99999.0 -99999.0
# Profile Curvature -99999.0 -99999.0
# TRI -99999.0 -99999.0
# NDVI -99999.0 -99999.0
# LULC 0.0 0.0
# Proximity_Road -99999.0 -99999.0
# Proximity_Rivers -99999.0 -99999.0
# Proximity_Faults -99999.0 -99999.0
# Max_Rainfall -99999.0 -99999.0

# %%
# ==========================================
# 7. CLOSE RASTERS
# ==========================================

for src in srcs.values():
    src.close()

print("\nAll susceptibility maps generated successfully.")
# Out:
# All susceptibility maps generated successfully.

# %%
for feature, path in raster_paths.items():

    print(feature)
    print(path)
# Out:
# Aspect
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Aspect.tif
# Elevation
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Elevation.tif
# Slope
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Slope.tif
# Plan Curvature
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Plan_Curvature.tif
# Profile Curvature
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Profile_Curvature.tif
# TRI
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_TRI.tif
# NDVI
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_NDVI.tif
# LULC
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_LULC.tif
# Proximity_Road
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Proximity_Road.tif
# Proximity_Rivers
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Proximity_Rivers.tif
# Proximity_Faults
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Proximity_Faults.tif
# Max_Rainfall
# /content/drive/MyDrive/cosesmic/layers/rasters/aligned_Max_Rainfall.tif

# %%
src = rasterio.open(
    raster_paths["Slope"]
)

arr = src.read(1)

print(np.unique(arr[:10, :10]))
print(np.unique(arr)[0:20])
# Out:
# [-99999.]
# [-9.9999000e+04  0.0000000e+00  3.8004362e-07  7.6008723e-07
#   1.0749256e-06  1.1401308e-06  1.3436571e-06  1.5201745e-06
#   1.6123885e-06  1.9002181e-06  2.1498513e-06  2.6603052e-06
#   3.0403489e-06  3.2247769e-06  4.2997026e-06  4.5605234e-06
#   4.5684342e-06  4.9405671e-06  5.3206104e-06  5.3746285e-06]
